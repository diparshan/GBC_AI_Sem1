# %% [markdown]
# <p style="font-family: Arial; font-size:3em;color:black;"> Lab Exercise 10</p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(5)  # creating pseudo-random numbers for reproducibility

# %%
# Let's consider the following A_orig matrix:

A_orig = np.array([[4, 2, 4, 5, 4, 2, 2], [4, 4, 3, 2, 2, 5, 4], [4, 1, 4, 7, 3, 6, 2], [8 ,1, 2, 0, 5, 0, 7], [4 , 5, 8, 7, 6, 2, 3]],dtype=float)
M, N = 5, 7
print (pd.DataFrame(A_orig).head())
# Out:
#      0    1    2    3    4    5    6
# 0  4.0  2.0  4.0  5.0  4.0  2.0  2.0
# 1  4.0  4.0  3.0  2.0  2.0  5.0  4.0
# 2  4.0  1.0  4.0  7.0  3.0  6.0  2.0
# 3  8.0  1.0  2.0  0.0  5.0  0.0  7.0
# 4  4.0  5.0  8.0  7.0  6.0  2.0  3.0

# %%
# Let's add some NaN(s) to  A_orig matrix

A = A_orig.copy()
A[3][1] = np.NaN
A[4][6] = np.NaN

A_df = pd.DataFrame(A)
print (A_df.head())
# Out:
#      0    1    2    3    4    5    6
# 0  4.0  2.0  4.0  5.0  4.0  2.0  2.0
# 1  4.0  4.0  3.0  2.0  2.0  5.0  4.0
# 2  4.0  1.0  4.0  7.0  3.0  6.0  2.0
# 3  8.0  NaN  2.0  0.0  5.0  0.0  7.0
# 4  4.0  5.0  8.0  7.0  6.0  2.0  NaN

# %%
def missing_error(original_matrix, reconstructed_matrix, missing_indices):
    errors = []
    for (i,j) in missing_indices:
        original_value=original_matrix[i,j]
        predicted_value=reconstructed_matrix[i,j]
        error=abs(original_value -predicted_value) / original_value*100
        errors.append(error)

    return np.mean(error)

# %%
# Fine tune K value such that the (average percentage) error for the 2 missing elements is minimum.
# Remember: this is an exercise where we have the actual values for missing elements. 
# In real-life scenarios missins elements are not known and you may need different metric(s)
# to assess the quality of your reconstructed matrix.
K = 1
P = np.abs(np.random.uniform(low=0, high=8, size=(M, K)))
Q = np.abs(np.random.uniform(low=0, high=8, size=(K, N)))
P = np.divide(P, K*P.max())
Q = np.divide(Q, K*Q.max())

# %%
def matrix_factorization(Rating_Matrix, P, Q, K, steps, alpha=0.001, beta=0.02):
    Q = Q.T
    for step in range(steps):
        for i in range(len(Rating_Matrix)):
            for j in range(len(Rating_Matrix[i])):
                if ~np.isnan(Rating_Matrix[i][j]):
                    eij = Rating_Matrix[i][j] - np.dot(P[i,:],Q[:,j])
                    for k in range(K):
                        P[i][k] = P[i][k] + alpha * (2 * eij * Q[k][j] - beta * P[i][k])
                        Q[k][j] = Q[k][j] + alpha * (2 * eij * P[i][k] - beta * Q[k][j])
        eRating_Matrix = np.dot(P,Q)
        e = 0
        for i in range(len(Rating_Matrix)):
            for j in range(len(Rating_Matrix[i])):
                if ~np.isnan(Rating_Matrix[i][j]):
                    e = e + pow(Rating_Matrix[i][j] - np.dot(P[i,:],Q[:,j]), 2)
                    for k in range(K):
                        e = e + (beta/2) * (pow(P[i][k],2) + pow(Q[k][j],2))
        print("Total error at step", step, "is", e)
        if e < 0.0001:
            break
    return P, Q.T

# %%
missing_indices = [(3,1), (4,6)]

for k in range(2, 10):
    P = np.abs(np.random.uniform(low=0, high=8, size=(M,K)))
    Q = np.abs(np.random.uniform(low=0, high=8, size=(K,N)))
    P = np.divide(P,K*P.max())
    Q = np.divide(Q,K*Q.max())

    print(f"testing k = {K}: p shape={P.shape}, q shape={Q.shape}")
    

    eP, eQ = matrix_factorization(A, P, Q.T, K, steps = 1000)
    eA = np.matmul(eP, eQ.T)

error = missing_error(A_orig, eA, missing_indices)
print(f"k={K}, Average Percentage Error = {error:.2f}%")
# Out:
# testing k = 1: p shape=(5, 1), q shape=(1, 7)
# Total error at step 0 is 569.8325890483403
# Total error at step 1 is 563.4903870633115
# Total error at step 2 is 556.765522058106
# Total error at step 3 is 549.6407842304311
# Total error at step 4 is 542.1006250081342
# Total error at step 5 is 534.131546342109
# Total error at step 6 is 525.7225249014075
# Total error at step 7 is 516.8654653197304
# Total error at step 8 is 507.5556742278923
# Total error at step 9 is 497.79234414313413
# Total error at step 10 is 487.5790334706258
# Total error at step 11 is 476.92412604627907
# Total error at step 12 is 465.8412510005195
# Total error at step 13 is 454.3496414814088
# Total error at step 14 is 442.4744092099624
# Total error at step 15 is 430.2467112387635
# Total error at step 16 is 417.70378593224757
# Total error at step 17 is 404.88883733476644
# Total error at step 18 is 391.850750921191
# Total error at step 19 is 378.64362930466604
# Total error at step 20 is 365.3261437302719
# Total error at step 21 is 351.96070586004714
# Total error at step 22 is 338.6124740157391
# Total error at step 23 is 325.3482180761791
# Total error at step 24 is 312.2350768721638
# Total error at step 25 is 299.3392503523779
# Total error at step 26 is 286.72467518689587
# Total error at step 27 is 274.45173611395694
# Total error at step 28 is 262.5760657077621
# Total error at step 29 is 251.1474821200537
# Total error at step 30 is 240.2091078288396
# Total error at step 31 is 229.79670295634048
# Total error at step 32 is 219.93823503873213
# Total error at step 33 is 210.65369420631808
# Total error at step 34 is 201.95514963673756
# Total error at step 35 is 193.84703093147644
# Total error at step 36 is 186.32660765745678
# Total error at step 37 is 179.38463238009246
# Total error at step 38 is 173.00610749157525
# Total error at step 39 is 167.17113410191186
# Total error at step 40 is 161.85580202178605
# Total error at step 41 is 157.03308301076126
# Total error at step 42 is 152.67369442594537
# Total error at step 43 is 148.7469065501322
# Total error at step 44 is 145.22127357630438
# Total error at step 45 is 142.06527491615574
# Total error at step 46 is 139.2478597311587
# Total error at step 47 is 136.73889303130636
# Total error at step 48 is 134.50950615492548
# Total error at step 49 is 132.53235785671464
# Total error at step 50 is 130.78181461062593
# Total error at step 51 is 129.2340601703632
# Total error at step 52 is 127.86714505900244
# Total error at step 53 is 126.66098663837333
# Total error at step 54 is 125.59732989947364
# Total error at step 55 is 124.65967826822894
# Total error at step 56 is 123.83320266839212
# Total error at step 57 is 123.10463593411416
# Total error at step 58 is 122.46215850316685
# Total error at step 59 is 121.89528020933707
# Total error at step 60 is 121.39472197014564
# Total error at step 61 is 120.95230025781706
# Total error at step 62 is 120.56081645808354
# Total error at step 63 is 120.21395256377384
# Total error at step 64 is 119.90617411220337
# Total error at step 65 is 119.63264084675107
# Total error at step 66 is 119.38912525093669
# Total error at step 67 is 119.17193885413667
# Total error at step 68 is 118.97786602831036
# Total error at step 69 is 118.80410487207887
# Total error at step 70 is 118.64821470079724
# Total error at step 71 is 118.5080696189025
# Total error at step 72 is 118.38181763531807
# Total error at step 73 is 118.26784478697459
# Total error at step 74 is 118.1647437538303
# Total error at step 75 is 118.07128647654642
# Total error at step 76 is 117.9864003216211
# Total error at step 77 is 117.90914737557718
# Total error at step 78 is 117.83870648769833
# Total error at step 79 is 117.77435771835022
# Total error at step 80 is 117.71546888608502
# Total error at step 81 is 117.66148394083841
# Total error at step 82 is 117.6119129221879
# Total error at step 83 is 117.56632329063957
# Total error at step 84 is 117.52433244619482
# Total error at step 85 is 117.48560127206116
# Total error at step 86 is 117.44982856242268
# Total error at step 87 is 117.41674621184406
# Total error at step 88 is 117.38611506031825
# Total error at step 89 is 117.3577213023893
# Total error at step 90 is 117.33137338137881
# Total error at step 91 is 117.30689930071021
# Total error at step 92 is 117.2841442938421
# Total error at step 93 is 117.26296880256052
# Total error at step 94 is 117.24324672049283
# Total error at step 95 is 117.22486386483861
# Total error at step 96 is 117.20771664458616
# Total error at step 97 is 117.19171089801665
# Total error at step 98 is 117.17676087618483
# Total error at step 99 is 117.16278835239827
# Total error at step 100 is 117.14972184057146
# Total error at step 101 is 117.13749590777209
# Total error at step 102 is 117.12605056836686
# Total error at step 103 is 117.11533074895966
# Total error at step 104 is 117.10528581484097
# Total error at step 105 is 117.09586914997254
# Total error at step 106 is 117.08703778364709
# Total error at step 107 is 117.07875205791419
# Total error at step 108 is 117.07097533068081
# Total error at step 109 is 117.06367371009082
# Total error at step 110 is 117.05681581638424
# Total error at step 111 is 117.05037256794962
# Total error at step 112 is 117.04431698871858
# Total error at step 113 is 117.03862403442957
# Total error at step 114 is 117.03327043560793
# Total error at step 115 is 117.02823455538858
# Total error at step 116 is 117.02349626054391
# Total error at step 117 is 117.01903680428771
# Total error at step 118 is 117.0148387195992
# Total error at step 119 is 117.01088572196835
# Total error at step 120 is 117.00716262059271
# Total error at step 121 is 117.00365523717282
# Total error at step 122 is 117.00035033155116
# Total error at step 123 is 116.99723553352848
# Total error at step 124 is 116.9942992802626
# Total error at step 125 is 116.99153075872636
# Total error at step 126 is 116.98891985275252
# Total error at step 127 is 116.98645709424913
# Total error at step 128 is 116.98413361820936
# Total error at step 129 is 116.98194112118132
# Total error at step 130 is 116.97987182289503
# Total error at step 131 is 116.97791843077661
# Total error at step 132 is 116.97607410710461
# Total error at step 133 is 116.97433243858787
# Total error at step 134 is 116.97268740816504
# Total error at step 135 is 116.97113336884549
# Total error at step 136 is 116.96966501942686
# Total error at step 137 is 116.96827738194038
# Total error at step 138 is 116.96696578068808
# Total error at step 139 is 116.96572582274833
# Total error at step 140 is 116.96455337983639
# Total error at step 141 is 116.96344457141723
# Total error at step 142 is 116.96239574897564
# Total error at step 143 is 116.96140348135764
# Total error at step 144 is 116.96046454110365
# Total error at step 145 is 116.9595758917001
# Total error at step 146 is 116.95873467568353
# Total error at step 147 is 116.95793820353484
# Total error at step 148 is 116.95718394330711
# Total error at step 149 is 116.95646951093511
# Total error at step 150 is 116.95579266117791
# Total error at step 151 is 116.95515127915051
# Total error at step 152 is 116.95454337240298
# Total error at step 153 is 116.95396706350982
# Total error at step 154 is 116.95342058313327
# Total error at step 155 is 116.95290226352995
# Total error at step 156 is 116.95241053246832
# Total error at step 157 is 116.95194390753157
# Total error at step 158 is 116.9515009907779
# Total error at step 159 is 116.95108046373599
# Total error at step 160 is 116.95068108271198
# Total error at step 161 is 116.95030167438814
# Total error at step 162 is 116.94994113169402
# Total error at step 163 is 116.9495984099315
# Total error at step 164 is 116.949272523138
# Total error at step 165 is 116.94896254067214
# Total error at step 166 is 116.94866758400651
# Total error at step 167 is 116.94838682371645
# Total error at step 168 is 116.94811947664942
# Total error at step 169 is 116.947864803266
# Total error at step 170 is 116.94762210513981
# Total error at step 171 is 116.94739072260745
# Total error at step 172 is 116.94717003255825
# Total error at step 173 is 116.94695944635552
# Total error at step 174 is 116.94675840788084
# Total error at step 175 is 116.94656639169385
# Total error at step 176 is 116.94638290130024
# Total error at step 177 is 116.94620746752145
# Total error at step 178 is 116.94603964695969
# Total error at step 179 is 116.94587902055254
# Total error at step 180 is 116.94572519221116
# Total error at step 181 is 116.94557778753811
# Total error at step 182 is 116.94543645261842
# Total error at step 183 is 116.9453008528815
# Total error at step 184 is 116.94517067202713
# Total error at step 185 is 116.94504561101401
# Total error at step 186 is 116.94492538710537
# Total error at step 187 is 116.94480973296987
# Total error at step 188 is 116.94469839583273
# Total error at step 189 is 116.94459113667546
# Total error at step 190 is 116.9444877294809
# Total error at step 191 is 116.94438796052054
# Total error at step 192 is 116.94429162768245
# Total error at step 193 is 116.9441985398363
# Total error at step 194 is 116.9441085162345
# Total error at step 195 is 116.94402138594683
# Total error at step 196 is 116.94393698732607
# Total error at step 197 is 116.94385516750384
# Total error at step 198 is 116.94377578191433
# Total error at step 199 is 116.94369869384431
# Total error at step 200 is 116.94362377400822
# Total error at step 201 is 116.94355090014642
# Total error at step 202 is 116.94347995664592
# Total error at step 203 is 116.9434108341817
# Total error at step 204 is 116.94334342937756
# Total error at step 205 is 116.94327764448633
# Total error at step 206 is 116.94321338708632
# Total error at step 207 is 116.94315056979546
# Total error at step 208 is 116.94308911000044
# Total error at step 209 is 116.94302892960056
# Total error at step 210 is 116.94296995476586
# Total error at step 211 is 116.94291211570798
# Total error at step 212 is 116.94285534646356
# Total error at step 213 is 116.9427995846895
# Total error at step 214 is 116.94274477146885
# Total error at step 215 is 116.94269085112764
# Total error at step 216 is 116.94263777106131
# Total error at step 217 is 116.94258548157038
# Total error at step 218 is 116.94253393570531
# Total error at step 219 is 116.9424830891193
# Total error at step 220 is 116.94243289992897
# Total error at step 221 is 116.94238332858288
# Total error at step 222 is 116.94233433773645
# Total error at step 223 is 116.94228589213448
# Total error at step 224 is 116.94223795849884
# Total error at step 225 is 116.94219050542286
# Total error at step 226 is 116.9421435032713
# Total error at step 227 is 116.94209692408518
# Total error at step 228 is 116.94205074149222
# Total error at step 229 is 116.94200493062168
# Total error at step 230 is 116.9419594680238
# Total error at step 231 is 116.94191433159357
# Total error at step 232 is 116.94186950049854
# Total error at step 233 is 116.94182495511019
# Total error at step 234 is 116.94178067693943
# Total error at step 235 is 116.94173664857506
# Total error at step 236 is 116.94169285362564
# Total error at step 237 is 116.9416492766643
# Total error at step 238 is 116.94160590317699
# Total error at step 239 is 116.94156271951279
# Total error at step 240 is 116.94151971283705
# Total error at step 241 is 116.9414768710872
# Total error at step 242 is 116.94143418293082
# Total error at step 243 is 116.94139163772576
# Total error at step 244 is 116.9413492254825
# Total error at step 245 is 116.94130693682845
# Total error at step 246 is 116.94126476297417
# Total error at step 247 is 116.94122269568129
# Total error at step 248 is 116.94118072723238
# Total error at step 249 is 116.94113885040176
# Total error at step 250 is 116.94109705842898
# Total error at step 251 is 116.94105534499245
# Total error at step 252 is 116.94101370418507
# Total error at step 253 is 116.94097213049157
# Total error at step 254 is 116.94093061876607
# Total error at step 255 is 116.94088916421177
# Total error at step 256 is 116.94084776236087
# Total error at step 257 is 116.94080640905636
# Total error at step 258 is 116.94076510043416
# Total error at step 259 is 116.94072383290664
# Total error at step 260 is 116.94068260314661
# Total error at step 261 is 116.9406414080724
# Total error at step 262 is 116.94060024483386
# Total error at step 263 is 116.94055911079879
# Total error at step 264 is 116.94051800354045
# Total error at step 265 is 116.94047692082528
# Total error at step 266 is 116.9404358606017
# Total error at step 267 is 116.94039482098927
# Total error at step 268 is 116.94035380026868
# Total error at step 269 is 116.94031279687188
# Total error at step 270 is 116.94027180937313
# Total error at step 271 is 116.94023083648035
# Total error at step 272 is 116.9401898770269
# Total error at step 273 is 116.94014892996395
# Total error at step 274 is 116.94010799435317
# Total error at step 275 is 116.9400670693596
# Total error at step 276 is 116.94002615424566
# Total error at step 277 is 116.93998524836437
# Total error at step 278 is 116.93994435115403
# Total error at step 279 is 116.93990346213239
# Total error at step 280 is 116.93986258089147
# Total error at step 281 is 116.93982170709293
# Total error at step 282 is 116.93978084046316
# Total error at step 283 is 116.93973998078884
# Total error at step 284 is 116.93969912791309
# Total error at step 285 is 116.93965828173125
# Total error at step 286 is 116.93961744218764
# Total error at step 287 is 116.9395766092714
# Total error at step 288 is 116.9395357830139
# Total error at step 289 is 116.93949496348522
# Total error at step 290 is 116.93945415079133
# Total error at step 291 is 116.93941334507139
# Total error at step 292 is 116.93937254649533
# Total error at step 293 is 116.93933175526091
# Total error at step 294 is 116.93929097159199
# Total error at step 295 is 116.93925019573595
# Total error at step 296 is 116.93920942796198
# Total error at step 297 is 116.93916866855875
# Total error at step 298 is 116.93912791783323
# Total error at step 299 is 116.93908717610833
# Total error at step 300 is 116.93904644372185
# Total error at step 301 is 116.93900572102454
# Total error at step 302 is 116.93896500837901
# Total error at step 303 is 116.93892430615848
# Total error at step 304 is 116.93888361474512
# Total error at step 305 is 116.93884293452949
# Total error at step 306 is 116.93880226590883
# Total error at step 307 is 116.93876160928664
# Total error at step 308 is 116.93872096507131
# Total error at step 309 is 116.93868033367542
# Total error at step 310 is 116.93863971551488
# Total error at step 311 is 116.93859911100826
# Total error at step 312 is 116.93855852057581
# Total error at step 313 is 116.93851794463919
# Total error at step 314 is 116.93847738362038
# Total error at step 315 is 116.93843683794155
# Total error at step 316 is 116.93839630802427
# Total error at step 317 is 116.93835579428902
# Total error at step 318 is 116.93831529715486
# Total error at step 319 is 116.9382748170389
# Total error at step 320 is 116.93823435435584
# Total error at step 321 is 116.93819390951782
# Total error at step 322 is 116.93815348293408
# Total error at step 323 is 116.93811307501028
# Total error at step 324 is 116.93807268614877
# Total error at step 325 is 116.93803231674784
# Total error at step 326 is 116.9379919672019
# Total error at step 327 is 116.9379516379009
# Total error at step 328 is 116.9379113292305
# Total error at step 329 is 116.93787104157158
# Total error at step 330 is 116.9378307753004
# Total error at step 331 is 116.93779053078806
# Total error at step 332 is 116.93775030840094
# Total error at step 333 is 116.9377101084999
# Total error at step 334 is 116.93766993144091
# Total error at step 335 is 116.9376297775743
# Total error at step 336 is 116.9375896472453
# Total error at step 337 is 116.93754954079351
# Total error at step 338 is 116.93750945855317
# Total error at step 339 is 116.93746940085292
# Total error at step 340 is 116.93742936801591
# Total error at step 341 is 116.93738936035962
# Total error at step 342 is 116.93734937819607
# Total error at step 343 is 116.93730942183177
# Total error at step 344 is 116.93726949156746
# Total error at step 345 is 116.93722958769844
# Total error at step 346 is 116.93718971051453
# Total error at step 347 is 116.93714986029991
# Total error at step 348 is 116.93711003733334
# Total error at step 349 is 116.93707024188807
# Total error at step 350 is 116.93703047423203
# Total error at step 351 is 116.9369907346277
# Total error at step 352 is 116.93695102333209
# Total error at step 353 is 116.93691134059725
# Total error at step 354 is 116.93687168666973
# Total error at step 355 is 116.93683206179094
# Total error at step 356 is 116.93679246619716
# Total error at step 357 is 116.93675290011964
# Total error at step 358 is 116.93671336378459
# Total error at step 359 is 116.9366738574133
# Total error at step 360 is 116.93663438122208
# Total error at step 361 is 116.93659493542253
# Total error at step 362 is 116.93655552022139
# Total error at step 363 is 116.9365161358207
# Total error at step 364 is 116.936476782418
# Total error at step 365 is 116.93643746020616
# Total error at step 366 is 116.93639816937355
# Total error at step 367 is 116.9363589101042
# Total error at step 368 is 116.9363196825777
# Total error at step 369 is 116.93628048696945
# Total error at step 370 is 116.93624132345057
# Total error at step 371 is 116.93620219218795
# Total error at step 372 is 116.93616309334463
# Total error at step 373 is 116.93612402707954
# Total error at step 374 is 116.93608499354757
# Total error at step 375 is 116.93604599289986
# Total error at step 376 is 116.93600702528376
# Total error at step 377 is 116.93596809084283
# Total error at step 378 is 116.93592918971702
# Total error at step 379 is 116.93589032204271
# Total error at step 380 is 116.93585148795266
# Total error at step 381 is 116.93581268757615
# Total error at step 382 is 116.93577392103926
# Total error at step 383 is 116.93573518846469
# Total error at step 384 is 116.93569648997165
# Total error at step 385 is 116.9356578256765
# Total error at step 386 is 116.93561919569206
# Total error at step 387 is 116.93558060012853
# Total error at step 388 is 116.93554203909272
# Total error at step 389 is 116.93550351268865
# Total error at step 390 is 116.93546502101754
# Total error at step 391 is 116.93542656417749
# Total error at step 392 is 116.93538814226415
# Total error at step 393 is 116.93534975537032
# Total error at step 394 is 116.93531140358614
# Total error at step 395 is 116.93527308699906
# Total error at step 396 is 116.93523480569415
# Total error at step 397 is 116.93519655975382
# Total error at step 398 is 116.93515834925817
# Total error at step 399 is 116.93512017428486
# Total error at step 400 is 116.93508203490917
# Total error at step 401 is 116.93504393120418
# Total error at step 402 is 116.93500586324066
# Total error at step 403 is 116.9349678310872
# Total error at step 404 is 116.93492983481032
# Total error at step 405 is 116.93489187447433
# Total error at step 406 is 116.93485395014156
# Total error at step 407 is 116.93481606187234
# Total error at step 408 is 116.93477820972504
# Total error at step 409 is 116.9347403937561
# Total error at step 410 is 116.93470261402011
# Total error at step 411 is 116.93466487056972
# Total error at step 412 is 116.93462716345599
# Total error at step 413 is 116.93458949272811
# Total error at step 414 is 116.93455185843351
# Total error at step 415 is 116.93451426061807
# Total error at step 416 is 116.93447669932598
# Total error at step 417 is 116.93443917459985
# Total error at step 418 is 116.93440168648063
# Total error at step 419 is 116.93436423500795
# Total error at step 420 is 116.93432682021975
# Total error at step 421 is 116.93428944215266
# Total error at step 422 is 116.93425210084189
# Total error at step 423 is 116.93421479632109
# Total error at step 424 is 116.93417752862268
# Total error at step 425 is 116.93414029777783
# Total error at step 426 is 116.9341031038163
# Total error at step 427 is 116.93406594676658
# Total error at step 428 is 116.93402882665602
# Total error at step 429 is 116.93399174351076
# Total error at step 430 is 116.93395469735566
# Total error at step 431 is 116.9339176882145
# Total error at step 432 is 116.93388071610985
# Total error at step 433 is 116.93384378106344
# Total error at step 434 is 116.93380688309567
# Total error at step 435 is 116.933770022226
# Total error at step 436 is 116.93373319847285
# Total error at step 437 is 116.93369641185362
# Total error at step 438 is 116.93365966238476
# Total error at step 439 is 116.93362295008187
# Total error at step 440 is 116.93358627495948
# Total error at step 441 is 116.93354963703128
# Total error at step 442 is 116.93351303631012
# Total error at step 443 is 116.93347647280784
# Total error at step 444 is 116.93343994653561
# Total error at step 445 is 116.93340345750374
# Total error at step 446 is 116.93336700572169
# Total error at step 447 is 116.93333059119816
# Total error at step 448 is 116.93329421394104
# Total error at step 449 is 116.93325787395761
# Total error at step 450 is 116.9332215712543
# Total error at step 451 is 116.93318530583684
# Total error at step 452 is 116.93314907771042
# Total error at step 453 is 116.93311288687939
# Total error at step 454 is 116.9330767333474
# Total error at step 455 is 116.93304061711765
# Total error at step 456 is 116.9330045381926
# Total error at step 457 is 116.93296849657408
# Total error at step 458 is 116.93293249226339
# Total error at step 459 is 116.93289652526121
# Total error at step 460 is 116.93286059556765
# Total error at step 461 is 116.9328247031823
# Total error at step 462 is 116.93278884810414
# Total error at step 463 is 116.93275303033175
# Total error at step 464 is 116.93271724986297
# Total error at step 465 is 116.93268150669546
# Total error at step 466 is 116.9326458008261
# Total error at step 467 is 116.93261013225147
# Total error at step 468 is 116.93257450096756
# Total error at step 469 is 116.93253890697004
# Total error at step 470 is 116.93250335025401
# Total error at step 471 is 116.93246783081426
# Total error at step 472 is 116.93243234864507
# Total error at step 473 is 116.93239690374024
# Total error at step 474 is 116.93236149609342
# Total error at step 475 is 116.93232612569764
# Total error at step 476 is 116.93229079254564
# Total error at step 477 is 116.93225549662968
# Total error at step 478 is 116.93222023794192
# Total error at step 479 is 116.93218501647387
# Total error at step 480 is 116.93214983221684
# Total error at step 481 is 116.93211468516188
# Total error at step 482 is 116.93207957529947
# Total error at step 483 is 116.9320445026201
# Total error at step 484 is 116.93200946711364
# Total error at step 485 is 116.93197446876977
# Total error at step 486 is 116.93193950757802
# Total error at step 487 is 116.9319045835274
# Total error at step 488 is 116.93186969660671
# Total error at step 489 is 116.93183484680465
# Total error at step 490 is 116.93180003410933
# Total error at step 491 is 116.93176525850895
# Total error at step 492 is 116.93173051999119
# Total error at step 493 is 116.93169581854359
# Total error at step 494 is 116.93166115415347
# Total error at step 495 is 116.93162652680785
# Total error at step 496 is 116.93159193649356
# Total error at step 497 is 116.93155738319722
# Total error at step 498 is 116.93152286690515
# Total error at step 499 is 116.93148838760364
# Total error at step 500 is 116.93145394527849
# Total error at step 501 is 116.93141953991558
# Total error at step 502 is 116.93138517150051
# Total error at step 503 is 116.93135084001845
# Total error at step 504 is 116.93131654545482
# Total error at step 505 is 116.93128228779453
# Total error at step 506 is 116.93124806702235
# Total error at step 507 is 116.93121388312309
# Total error at step 508 is 116.93117973608105
# Total error at step 509 is 116.9311456258807
# Total error at step 510 is 116.93111155250614
# Total error at step 511 is 116.93107751594137
# Total error at step 512 is 116.93104351617028
# Total error at step 513 is 116.9310095531766
# Total error at step 514 is 116.93097562694379
# Total error at step 515 is 116.93094173745546
# Total error at step 516 is 116.93090788469475
# Total error at step 517 is 116.93087406864481
# Total error at step 518 is 116.93084028928874
# Total error at step 519 is 116.93080654660947
# Total error at step 520 is 116.93077284058971
# Total error at step 521 is 116.93073917121217
# Total error at step 522 is 116.93070553845929
# Total error at step 523 is 116.93067194231367
# Total error at step 524 is 116.93063838275751
# Total error at step 525 is 116.93060485977306
# Total error at step 526 is 116.93057137334246
# Total error at step 527 is 116.93053792344764
# Total error at step 528 is 116.93050451007059
# Total error at step 529 is 116.93047113319315
# Total error at step 530 is 116.93043779279692
# Total error at step 531 is 116.93040448886366
# Total error at step 532 is 116.93037122137478
# Total error at step 533 is 116.9303379903118
# Total error at step 534 is 116.93030479565617
# Total error at step 535 is 116.93027163738905
# Total error at step 536 is 116.93023851549171
# Total error at step 537 is 116.93020542994529
# Total error at step 538 is 116.93017238073082
# Total error at step 539 is 116.93013936782934
# Total error at step 540 is 116.93010639122167
# Total error at step 541 is 116.93007345088878
# Total error at step 542 is 116.93004054681136
# Total error at step 543 is 116.93000767897018
# Total error at step 544 is 116.92997484734582
# Total error at step 545 is 116.9299420519189
# Total error at step 546 is 116.92990929267
# Total error at step 547 is 116.92987656957952
# Total error at step 548 is 116.9298438826279
# Total error at step 549 is 116.92981123179551
# Total error at step 550 is 116.92977861706271
# Total error at step 551 is 116.92974603840966
# Total error at step 552 is 116.9297134958166
# Total error at step 553 is 116.92968098926369
# Total error at step 554 is 116.92964851873103
# Total error at step 555 is 116.92961608419873
# Total error at step 556 is 116.92958368564678
# Total error at step 557 is 116.92955132305514
# Total error at step 558 is 116.92951899640373
# Total error at step 559 is 116.92948670567253
# Total error at step 560 is 116.92945445084135
# Total error at step 561 is 116.92942223188996
# Total error at step 562 is 116.92939004879814
# Total error at step 563 is 116.92935790154579
# Total error at step 564 is 116.92932579011244
# Total error at step 565 is 116.92929371447786
# Total error at step 566 is 116.9292616746216
# Total error at step 567 is 116.92922967052341
# Total error at step 568 is 116.9291977021628
# Total error at step 569 is 116.9291657695193
# Total error at step 570 is 116.92913387257249
# Total error at step 571 is 116.92910201130186
# Total error at step 572 is 116.92907018568681
# Total error at step 573 is 116.92903839570688
# Total error at step 574 is 116.92900664134147
# Total error at step 575 is 116.92897492256994
# Total error at step 576 is 116.92894323937169
# Total error at step 577 is 116.92891159172603
# Total error at step 578 is 116.92887997961235
# Total error at step 579 is 116.92884840301001
# Total error at step 580 is 116.92881686189811
# Total error at step 581 is 116.92878535625616
# Total error at step 582 is 116.9287538860633
# Total error at step 583 is 116.9287224512987
# Total error at step 584 is 116.92869105194168
# Total error at step 585 is 116.92865968797138
# Total error at step 586 is 116.92862835936702
# Total error at step 587 is 116.92859706610777
# Total error at step 588 is 116.92856580817286
# Total error at step 589 is 116.92853458554124
# Total error at step 590 is 116.92850339819226
# Total error at step 591 is 116.92847224610487
# Total error at step 592 is 116.92844112925833
# Total error at step 593 is 116.92841004763159
# Total error at step 594 is 116.92837900120382
# Total error at step 595 is 116.92834798995408
# Total error at step 596 is 116.9283170138614
# Total error at step 597 is 116.9282860729049
# Total error at step 598 is 116.92825516706355
# Total error at step 599 is 116.9282242963165
# Total error at step 600 is 116.92819346064262
# Total error at step 601 is 116.92816266002109
# Total error at step 602 is 116.92813189443085
# Total error at step 603 is 116.92810116385093
# Total error at step 604 is 116.92807046826032
# Total error at step 605 is 116.92803980763797
# Total error at step 606 is 116.92800918196298
# Total error at step 607 is 116.92797859121427
# Total error at step 608 is 116.9279480353708
# Total error at step 609 is 116.92791751441166
# Total error at step 610 is 116.92788702831571
# Total error at step 611 is 116.927856577062
# Total error at step 612 is 116.92782616062944
# Total error at step 613 is 116.92779577899694
# Total error at step 614 is 116.92776543214363
# Total error at step 615 is 116.92773512004835
# Total error at step 616 is 116.92770484269012
# Total error at step 617 is 116.9276746000479
# Total error at step 618 is 116.92764439210059
# Total error at step 619 is 116.9276142188272
# Total error at step 620 is 116.92758408020666
# Total error at step 621 is 116.92755397621801
# Total error at step 622 is 116.92752390684001
# Total error at step 623 is 116.92749387205184
# Total error at step 624 is 116.9274638718323
# Total error at step 625 is 116.92743390616045
# Total error at step 626 is 116.92740397501518
# Total error at step 627 is 116.92737407837551
# Total error at step 628 is 116.92734421622035
# Total error at step 629 is 116.92731438852866
# Total error at step 630 is 116.92728459527952
# Total error at step 631 is 116.92725483645171
# Total error at step 632 is 116.92722511202436
# Total error at step 633 is 116.9271954219764
# Total error at step 634 is 116.9271657662868
# Total error at step 635 is 116.92713614493451
# Total error at step 636 is 116.92710655789858
# Total error at step 637 is 116.92707700515795
# Total error at step 638 is 116.92704748669159
# Total error at step 639 is 116.92701800247853
# Total error at step 640 is 116.92698855249779
# Total error at step 641 is 116.92695913672831
# Total error at step 642 is 116.9269297551492
# Total error at step 643 is 116.92690040773937
# Total error at step 644 is 116.92687109447783
# Total error at step 645 is 116.9268418153437
# Total error at step 646 is 116.92681257031595
# Total error at step 647 is 116.92678335937362
# Total error at step 648 is 116.92675418249569
# Total error at step 649 is 116.92672503966135
# Total error at step 650 is 116.92669593084945
# Total error at step 651 is 116.92666685603923
# Total error at step 652 is 116.92663781520959
# Total error at step 653 is 116.92660880833972
# Total error at step 654 is 116.92657983540862
# Total error at step 655 is 116.92655089639544
# Total error at step 656 is 116.92652199127916
# Total error at step 657 is 116.92649312003894
# Total error at step 658 is 116.92646428265394
# Total error at step 659 is 116.92643547910313
# Total error at step 660 is 116.92640670936568
# Total error at step 661 is 116.92637797342076
# Total error at step 662 is 116.92634927124743
# Total error at step 663 is 116.92632060282484
# Total error at step 664 is 116.92629196813213
# Total error at step 665 is 116.92626336714844
# Total error at step 666 is 116.92623479985296
# Total error at step 667 is 116.92620626622478
# Total error at step 668 is 116.92617776624316
# Total error at step 669 is 116.92614929988726
# Total error at step 670 is 116.92612086713618
# Total error at step 671 is 116.92609246796911
# Total error at step 672 is 116.92606410236549
# Total error at step 673 is 116.92603577030427
# Total error at step 674 is 116.92600747176472
# Total error at step 675 is 116.92597920672611
# Total error at step 676 is 116.92595097516768
# Total error at step 677 is 116.92592277706869
# Total error at step 678 is 116.92589461240829
# Total error at step 679 is 116.92586648116581
# Total error at step 680 is 116.92583838332057
# Total error at step 681 is 116.92581031885179
# Total error at step 682 is 116.92578228773866
# Total error at step 683 is 116.92575428996065
# Total error at step 684 is 116.92572632549694
# Total error at step 685 is 116.9256983943269
# Total error at step 686 is 116.92567049642983
# Total error at step 687 is 116.92564263178508
# Total error at step 688 is 116.92561480037189
# Total error at step 689 is 116.92558700216983
# Total error at step 690 is 116.92555923715798
# Total error at step 691 is 116.9255315053159
# Total error at step 692 is 116.92550380662291
# Total error at step 693 is 116.92547614105837
# Total error at step 694 is 116.92544850860175
# Total error at step 695 is 116.92542090923233
# Total error at step 696 is 116.92539334292964
# Total error at step 697 is 116.92536580967298
# Total error at step 698 is 116.9253383094419
# Total error at step 699 is 116.92531084221582
# Total error at step 700 is 116.92528340797415
# Total error at step 701 is 116.92525600669629
# Total error at step 702 is 116.92522863836184
# Total error at step 703 is 116.9252013029502
# Total error at step 704 is 116.92517400044092
# Total error at step 705 is 116.92514673081345
# Total error at step 706 is 116.9251194940473
# Total error at step 707 is 116.92509229012201
# Total error at step 708 is 116.92506511901706
# Total error at step 709 is 116.92503798071203
# Total error at step 710 is 116.92501087518644
# Total error at step 711 is 116.92498380241996
# Total error at step 712 is 116.92495676239199
# Total error at step 713 is 116.92492975508226
# Total error at step 714 is 116.92490278047025
# Total error at step 715 is 116.92487583853557
# Total error at step 716 is 116.92484892925786
# Total error at step 717 is 116.92482205261678
# Total error at step 718 is 116.92479520859185
# Total error at step 719 is 116.92476839716277
# Total error at step 720 is 116.92474161830917
# Total error at step 721 is 116.92471487201077
# Total error at step 722 is 116.92468815824716
# Total error at step 723 is 116.92466147699805
# Total error at step 724 is 116.92463482824316
# Total error at step 725 is 116.92460821196217
# Total error at step 726 is 116.9245816281347
# Total error at step 727 is 116.92455507674067
# Total error at step 728 is 116.92452855775969
# Total error at step 729 is 116.92450207117145
# Total error at step 730 is 116.92447561695579
# Total error at step 731 is 116.92444919509241
# Total error at step 732 is 116.92442280556114
# Total error at step 733 is 116.92439644834174
# Total error at step 734 is 116.92437012341396
# Total error at step 735 is 116.92434383075765
# Total error at step 736 is 116.92431757035267
# Total error at step 737 is 116.92429134217873
# Total error at step 738 is 116.92426514621577
# Total error at step 739 is 116.92423898244357
# Total error at step 740 is 116.92421285084207
# Total error at step 741 is 116.92418675139098
# Total error at step 742 is 116.92416068407033
# Total error at step 743 is 116.9241346488599
# Total error at step 744 is 116.92410864573971
# Total error at step 745 is 116.92408267468957
# Total error at step 746 is 116.92405673568945
# Total error at step 747 is 116.92403082871922
# Total error at step 748 is 116.9240049537589
# Total error at step 749 is 116.9239791107884
# Total error at step 750 is 116.92395329978764
# Total error at step 751 is 116.92392752073671
# Total error at step 752 is 116.92390177361544
# Total error at step 753 is 116.92387605840396
# Total error at step 754 is 116.92385037508221
# Total error at step 755 is 116.92382472363019
# Total error at step 756 is 116.923799104028
# Total error at step 757 is 116.92377351625558
# Total error at step 758 is 116.92374796029307
# Total error at step 759 is 116.92372243612041
# Total error at step 760 is 116.92369694371774
# Total error at step 761 is 116.92367148306528
# Total error at step 762 is 116.92364605414281
# Total error at step 763 is 116.92362065693067
# Total error at step 764 is 116.92359529140896
# Total error at step 765 is 116.9235699575577
# Total error at step 766 is 116.92354465535705
# Total error at step 767 is 116.92351938478716
# Total error at step 768 is 116.92349414582823
# Total error at step 769 is 116.92346893846036
# Total error at step 770 is 116.92344376266382
# Total error at step 771 is 116.9234186184187
# Total error at step 772 is 116.92339350570518
# Total error at step 773 is 116.9233684245036
# Total error at step 774 is 116.92334337479403
# Total error at step 775 is 116.92331835655686
# Total error at step 776 is 116.92329336977213
# Total error at step 777 is 116.92326841442025
# Total error at step 778 is 116.92324349048144
# Total error at step 779 is 116.92321859793596
# Total error at step 780 is 116.92319373676409
# Total error at step 781 is 116.92316890694616
# Total error at step 782 is 116.92314410846237
# Total error at step 783 is 116.92311934129319
# Total error at step 784 is 116.92309460541883
# Total error at step 785 is 116.92306990081968
# Total error at step 786 is 116.92304522747604
# Total error at step 787 is 116.92302058536833
# Total error at step 788 is 116.92299597447689
# Total error at step 789 is 116.9229713947821
# Total error at step 790 is 116.92294684626437
# Total error at step 791 is 116.92292232890408
# Total error at step 792 is 116.92289784268165
# Total error at step 793 is 116.9228733875775
# Total error at step 794 is 116.9228489635721
# Total error at step 795 is 116.92282457064576
# Total error at step 796 is 116.92280020877907
# Total error at step 797 is 116.92277587795252
# Total error at step 798 is 116.92275157814646
# Total error at step 799 is 116.92272730934151
# Total error at step 800 is 116.92270307151807
# Total error at step 801 is 116.92267886465669
# Total error at step 802 is 116.92265468873794
# Total error at step 803 is 116.92263054374217
# Total error at step 804 is 116.92260642965013
# Total error at step 805 is 116.9225823464423
# Total error at step 806 is 116.92255829409922
# Total error at step 807 is 116.92253427260144
# Total error at step 808 is 116.92251028192963
# Total error at step 809 is 116.9224863220643
# Total error at step 810 is 116.92246239298613
# Total error at step 811 is 116.92243849467565
# Total error at step 812 is 116.92241462711365
# Total error at step 813 is 116.92239079028055
# Total error at step 814 is 116.92236698415712
# Total error at step 815 is 116.92234320872403
# Total error at step 816 is 116.92231946396188
# Total error at step 817 is 116.92229574985149
# Total error at step 818 is 116.92227206637338
# Total error at step 819 is 116.9222484135084
# Total error at step 820 is 116.9222247912371
# Total error at step 821 is 116.92220119954035
# Total error at step 822 is 116.92217763839886
# Total error at step 823 is 116.92215410779333
# Total error at step 824 is 116.92213060770462
# Total error at step 825 is 116.9221071381133
# Total error at step 826 is 116.9220836990003
# Total error at step 827 is 116.92206029034637
# Total error at step 828 is 116.92203691213228
# Total error at step 829 is 116.92201356433891
# Total error at step 830 is 116.92199024694703
# Total error at step 831 is 116.92196695993748
# Total error at step 832 is 116.92194370329112
# Total error at step 833 is 116.92192047698876
# Total error at step 834 is 116.92189728101131
# Total error at step 835 is 116.92187411533956
# Total error at step 836 is 116.9218509799546
# Total error at step 837 is 116.92182787483708
# Total error at step 838 is 116.921804799968
# Total error at step 839 is 116.92178175532835
# Total error at step 840 is 116.92175874089897
# Total error at step 841 is 116.9217357566608
# Total error at step 842 is 116.92171280259481
# Total error at step 843 is 116.92168987868193
# Total error at step 844 is 116.92166698490324
# Total error at step 845 is 116.92164412123962
# Total error at step 846 is 116.92162128767201
# Total error at step 847 is 116.92159848418157
# Total error at step 848 is 116.9215757107492
# Total error at step 849 is 116.92155296735595
# Total error at step 850 is 116.92153025398282
# Total error at step 851 is 116.92150757061091
# Total error at step 852 is 116.92148491722126
# Total error at step 853 is 116.92146229379492
# Total error at step 854 is 116.92143970031293
# Total error at step 855 is 116.92141713675646
# Total error at step 856 is 116.92139460310656
# Total error at step 857 is 116.92137209934438
# Total error at step 858 is 116.92134962545096
# Total error at step 859 is 116.92132718140748
# Total error at step 860 is 116.9213047671951
# Total error at step 861 is 116.92128238279487
# Total error at step 862 is 116.92126002818807
# Total error at step 863 is 116.92123770335577
# Total error at step 864 is 116.9212154082793
# Total error at step 865 is 116.9211931429397
# Total error at step 866 is 116.92117090731824
# Total error at step 867 is 116.92114870139615
# Total error at step 868 is 116.92112652515459
# Total error at step 869 is 116.92110437857484
# Total error at step 870 is 116.92108226163816
# Total error at step 871 is 116.92106017432576
# Total error at step 872 is 116.92103811661893
# Total error at step 873 is 116.92101608849893
# Total error at step 874 is 116.92099408994711
# Total error at step 875 is 116.9209721209447
# Total error at step 876 is 116.92095018147302
# Total error at step 877 is 116.92092827151342
# Total error at step 878 is 116.9209063910472
# Total error at step 879 is 116.9208845400556
# Total error at step 880 is 116.92086271852021
# Total error at step 881 is 116.92084092642223
# Total error at step 882 is 116.92081916374303
# Total error at step 883 is 116.92079743046402
# Total error at step 884 is 116.92077572656659
# Total error at step 885 is 116.92075405203217
# Total error at step 886 is 116.92073240684212
# Total error at step 887 is 116.92071079097792
# Total error at step 888 is 116.92068920442095
# Total error at step 889 is 116.92066764715271
# Total error at step 890 is 116.92064611915458
# Total error at step 891 is 116.92062462040808
# Total error at step 892 is 116.92060315089469
# Total error at step 893 is 116.92058171059585
# Total error at step 894 is 116.92056029949308
# Total error at step 895 is 116.92053891756795
# Total error at step 896 is 116.92051756480187
# Total error at step 897 is 116.92049624117642
# Total error at step 898 is 116.9204749466731
# Total error at step 899 is 116.92045368127353
# Total error at step 900 is 116.92043244495925
# Total error at step 901 is 116.92041123771178
# Total error at step 902 is 116.92039005951274
# Total error at step 903 is 116.92036891034371
# Total error at step 904 is 116.9203477901863
# Total error at step 905 is 116.92032669902211
# Total error at step 906 is 116.92030563683272
# Total error at step 907 is 116.92028460359985
# Total error at step 908 is 116.92026359930512
# Total error at step 909 is 116.9202426239301
# Total error at step 910 is 116.9202216774565
# Total error at step 911 is 116.92020075986602
# Total error at step 912 is 116.9201798711403
# Total error at step 913 is 116.9201590112611
# Total error at step 914 is 116.92013818021005
# Total error at step 915 is 116.92011737796892
# Total error at step 916 is 116.92009660451936
# Total error at step 917 is 116.92007585984318
# Total error at step 918 is 116.92005514392213
# Total error at step 919 is 116.92003445673788
# Total error at step 920 is 116.92001379827225
# Total error at step 921 is 116.91999316850706
# Total error at step 922 is 116.91997256742401
# Total error at step 923 is 116.91995199500496
# Total error at step 924 is 116.91993145123168
# Total error at step 925 is 116.91991093608598
# Total error at step 926 is 116.91989044954971
# Total error at step 927 is 116.91986999160471
# Total error at step 928 is 116.9198495622328
# Total error at step 929 is 116.9198291614159
# Total error at step 930 is 116.91980878913584
# Total error at step 931 is 116.91978844537442
# Total error at step 932 is 116.91976813011364
# Total error at step 933 is 116.91974784333536
# Total error at step 934 is 116.91972758502149
# Total error at step 935 is 116.91970735515395
# Total error at step 936 is 116.91968715371463
# Total error at step 937 is 116.91966698068555
# Total error at step 938 is 116.9196468360486
# Total error at step 939 is 116.91962671978574
# Total error at step 940 is 116.91960663187898
# Total error at step 941 is 116.91958657231027
# Total error at step 942 is 116.91956654106157
# Total error at step 943 is 116.91954653811491
# Total error at step 944 is 116.91952656345235
# Total error at step 945 is 116.91950661705586
# Total error at step 946 is 116.91948669890745
# Total error at step 947 is 116.91946680898916
# Total error at step 948 is 116.91944694728312
# Total error at step 949 is 116.91942711377138
# Total error at step 950 is 116.9194073084359
# Total error at step 951 is 116.91938753125882
# Total error at step 952 is 116.91936778222227
# Total error at step 953 is 116.91934806130834
# Total error at step 954 is 116.91932836849911
# Total error at step 955 is 116.9193087037767
# Total error at step 956 is 116.91928906712326
# Total error at step 957 is 116.91926945852099
# Total error at step 958 is 116.91924987795188
# Total error at step 959 is 116.91923032539833
# Total error at step 960 is 116.91921080084225
# Total error at step 961 is 116.91919130426602
# Total error at step 962 is 116.91917183565178
# Total error at step 963 is 116.91915239498168
# Total error at step 964 is 116.91913298223798
# Total error at step 965 is 116.9191135974029
# Total error at step 966 is 116.91909424045863
# Total error at step 967 is 116.91907491138747
# Total error at step 968 is 116.91905561017165
# Total error at step 969 is 116.91903633679341
# Total error at step 970 is 116.91901709123509
# Total error at step 971 is 116.91899787347892
# Total error at step 972 is 116.91897868350713
# Total error at step 973 is 116.91895952130217
# Total error at step 974 is 116.91894038684623
# Total error at step 975 is 116.91892128012175
# Total error at step 976 is 116.9189022011109
# Total error at step 977 is 116.91888314979616
# Total error at step 978 is 116.91886412615982
# Total error at step 979 is 116.91884513018428
# Total error at step 980 is 116.91882616185188
# Total error at step 981 is 116.91880722114495
# Total error at step 982 is 116.91878830804599
# Total error at step 983 is 116.9187694225374
# Total error at step 984 is 116.91875056460152
# Total error at step 985 is 116.91873173422083
# Total error at step 986 is 116.91871293137767
# Total error at step 987 is 116.91869415605461
# Total error at step 988 is 116.91867540823401
# Total error at step 989 is 116.91865668789836
# Total error at step 990 is 116.91863799503017
# Total error at step 991 is 116.91861932961186
# Total error at step 992 is 116.91860069162595
# Total error at step 993 is 116.91858208105492
# Total error at step 994 is 116.91856349788128
# Total error at step 995 is 116.91854494208764
# Total error at step 996 is 116.91852641365642
# Total error at step 997 is 116.91850791257022
# Total error at step 998 is 116.91848943881158
# Total error at step 999 is 116.91847099236307
# testing k = 1: p shape=(5, 1), q shape=(1, 7)
# Total error at step 0 is 579.8672554563052
# Total error at step 1 is 573.0784167163212
# Total error at step 2 is 565.9842694673544
# Total error at step 3 is 558.5615847032348
# Total error at step 4 is 550.7892071915014
# Total error at step 5 is 542.6483509177062
# Total error at step 6 is 534.1229363136273
# Total error at step 7 is 525.1999634660968
# Total error at step 8 is 515.8699135001035
# Total error at step 9 is 506.1271680520635
# Total error at step 10 is 495.9704342780785
# Total error at step 11 is 485.4031602965855
# Total error at step 12 is 474.4339235047851
# Total error at step 13 is 463.07677203372526
# Total error at step 14 is 451.3514979533868
# Total error at step 15 is 439.28381996578247
# Total error at step 16 is 426.90545349573995
# Total error at step 17 is 414.2540475505384
# Total error at step 18 is 401.372970664414
# Total error at step 19 is 388.31093277948196
# Total error at step 20 is 375.1214360274943
# Total error at step 21 is 361.86205490444314
# Total error at step 22 is 348.59355494355856
# Total error at step 23 is 335.37886819758177
# Total error at step 24 is 322.28195300169193
# Total error at step 25 is 309.3665738717244
# Total error at step 26 is 296.6950442385499
# Total error at step 27 is 284.32697932511104
# Total error at step 28 is 272.31810827879315
# Total error at step 29 is 260.7191933443035
# Total error at step 30 is 249.57509934968274
# Total error at step 31 is 238.9240493364838
# Total error at step 32 is 228.79709234295103
# Total error at step 33 is 219.21779793178297
# Total error at step 34 is 210.20217997685847
# Total error at step 35 is 201.75884046299188
# Total error at step 36 is 193.88931351721266
# Total error at step 37 is 186.58858132064648
# Total error at step 38 is 179.845727451648
# Total error at step 39 is 173.64468981703868
# Total error at step 40 is 167.9650746042358
# Total error at step 41 is 162.78299436467944
# Total error at step 42 is 158.07189697604812
# Total error at step 43 is 153.8033572818445
# Total error at step 44 is 149.94780909472303
# Total error at step 45 is 146.47520142755968
# Total error at step 46 is 143.3555688142238
# Total error at step 47 is 140.55951103684953
# Total error at step 48 is 138.05858224182316
# ...
# Total error at step 664 is 116.91745920993954
# Total error at step 665 is 116.91744232546233
# Total error at step 666 is 116.91742546728223
# Total error at step 667 is 116.91740863538226
# Total error at step 668 is 116.91739182974548
# Total error at step 669 is 116.91737505035516
# Total error at step 670 is 116.91735829719421
# Total error at step 671 is 116.91734157024594
# Total error at step 672 is 116.91732486949337
# Total error at step 673 is 116.91730819491968
# Total error at step 674 is 116.91729154650791
# Total error at step 675 is 116.91727492424141
# Total error at step 676 is 116.91725832810329
# Total error at step 677 is 116.91724175807668
# Total error at step 678 is 116.91722521414482
# Total error at step 679 is 116.91720869629088
# Total error at step 680 is 116.91719220449819
# Total error at step 681 is 116.91717573874988
# Total error at step 682 is 116.91715929902915
# Total error at step 683 is 116.91714288531932
# Total error at step 684 is 116.91712649760372
# Total error at step 685 is 116.91711013586544
# Total error at step 686 is 116.91709380008791
# Total error at step 687 is 116.91707749025433
# Total error at step 688 is 116.91706120634807
# Total error at step 689 is 116.91704494835238
# Total error at step 690 is 116.91702871625064
# Total error at step 691 is 116.91701251002611
# Total error at step 692 is 116.91699632966218
# Total error at step 693 is 116.9169801751422
# Total error at step 694 is 116.91696404644959
# Total error at step 695 is 116.91694794356758
# Total error at step 696 is 116.91693186647967
# Total error at step 697 is 116.91691581516916
# Total error at step 698 is 116.91689978961955
# Total error at step 699 is 116.9168837898142
# Total error at step 700 is 116.91686781573651
# Total error at step 701 is 116.91685186736997
# Total error at step 702 is 116.91683594469804
# Total error at step 703 is 116.91682004770404
# Total error at step 704 is 116.91680417637158
# Total error at step 705 is 116.91678833068411
# Total error at step 706 is 116.91677251062504
# Total error at step 707 is 116.91675671617789
# Total error at step 708 is 116.91674094732619
# Total error at step 709 is 116.91672520405345
# Total error at step 710 is 116.91670948634314
# Total error at step 711 is 116.91669379417884
# Total error at step 712 is 116.91667812754407
# Total error at step 713 is 116.91666248642245
# Total error at step 714 is 116.91664687079744
# Total error at step 715 is 116.91663128065275
# Total error at step 716 is 116.91661571597177
# Total error at step 717 is 116.91660017673826
# Total error at step 718 is 116.91658466293573
# Total error at step 719 is 116.91656917454783
# Total error at step 720 is 116.91655371155815
# Total error at step 721 is 116.91653827395035
# Total error at step 722 is 116.91652286170802
# Total error at step 723 is 116.91650747481489
# Total error at step 724 is 116.91649211325462
# Total error at step 725 is 116.91647677701079
# Total error at step 726 is 116.9164614660671
# Total error at step 727 is 116.9164461804073
# Total error at step 728 is 116.91643092001512
# Total error at step 729 is 116.91641568487412
# Total error at step 730 is 116.91640047496811
# Total error at step 731 is 116.91638529028084
# Total error at step 732 is 116.91637013079598
# Total error at step 733 is 116.91635499649738
# Total error at step 734 is 116.91633988736871
# Total error at step 735 is 116.91632480339372
# Total error at step 736 is 116.9163097445563
# Total error at step 737 is 116.91629471084006
# Total error at step 738 is 116.9162797022289
# Total error at step 739 is 116.91626471870666
# Total error at step 740 is 116.91624976025709
# Total error at step 741 is 116.91623482686406
# Total error at step 742 is 116.91621991851135
# Total error at step 743 is 116.91620503518286
# Total error at step 744 is 116.9161901768624
# Total error at step 745 is 116.91617534353384
# Total error at step 746 is 116.91616053518096
# Total error at step 747 is 116.91614575178787
# Total error at step 748 is 116.91613099333827
# Total error at step 749 is 116.9161162598161
# Total error at step 750 is 116.91610155120529
# Total error at step 751 is 116.91608686748978
# Total error at step 752 is 116.91607220865338
# Total error at step 753 is 116.9160575746802
# Total error at step 754 is 116.91604296555403
# Total error at step 755 is 116.91602838125891
# Total error at step 756 is 116.91601382177882
# Total error at step 757 is 116.91599928709765
# Total error at step 758 is 116.91598477719945
# Total error at step 759 is 116.9159702920682
# Total error at step 760 is 116.9159558316879
# Total error at step 761 is 116.91594139604256
# Total error at step 762 is 116.91592698511619
# Total error at step 763 is 116.91591259889282
# Total error at step 764 is 116.91589823735653
# Total error at step 765 is 116.9158839004913
# Total error at step 766 is 116.91586958828123
# Total error at step 767 is 116.91585530071042
# Total error at step 768 is 116.91584103776287
# Total error at step 769 is 116.91582679942273
# Total error at step 770 is 116.91581258567406
# Total error at step 771 is 116.91579839650095
# Total error at step 772 is 116.9157842318875
# Total error at step 773 is 116.91577009181796
# Total error at step 774 is 116.91575597627629
# Total error at step 775 is 116.91574188524676
# Total error at step 776 is 116.91572781871344
# Total error at step 777 is 116.9157137766605
# Total error at step 778 is 116.91569975907213
# Total error at step 779 is 116.91568576593255
# Total error at step 780 is 116.91567179722588
# Total error at step 781 is 116.91565785293629
# Total error at step 782 is 116.91564393304809
# Total error at step 783 is 116.91563003754538
# Total error at step 784 is 116.91561616641245
# Total error at step 785 is 116.91560231963352
# Total error at step 786 is 116.91558849719284
# Total error at step 787 is 116.91557469907464
# Total error at step 788 is 116.91556092526321
# Total error at step 789 is 116.91554717574276
# Total error at step 790 is 116.91553345049762
# Total error at step 791 is 116.91551974951207
# Total error at step 792 is 116.91550607277034
# Total error at step 793 is 116.91549242025685
# Total error at step 794 is 116.91547879195582
# Total error at step 795 is 116.91546518785162
# Total error at step 796 is 116.91545160792859
# Total error at step 797 is 116.91543805217101
# Total error at step 798 is 116.91542452056326
# Total error at step 799 is 116.91541101308974
# Total error at step 800 is 116.91539752973479
# Total error at step 801 is 116.91538407048277
# Total error at step 802 is 116.91537063531807
# Total error at step 803 is 116.91535722422508
# Total error at step 804 is 116.91534383718822
# Total error at step 805 is 116.91533047419193
# Total error at step 806 is 116.91531713522059
# Total error at step 807 is 116.9153038202586
# Total error at step 808 is 116.91529052929046
# Total error at step 809 is 116.91527726230065
# Total error at step 810 is 116.9152640192735
# Total error at step 811 is 116.91525080019363
# Total error at step 812 is 116.91523760504535
# Total error at step 813 is 116.91522443381325
# Total error at step 814 is 116.91521128648182
# Total error at step 815 is 116.91519816303556
# Total error at step 816 is 116.91518506345895
# Total error at step 817 is 116.91517198773654
# Total error at step 818 is 116.91515893585286
# Total error at step 819 is 116.91514590779238
# Total error at step 820 is 116.9151329035397
# Total error at step 821 is 116.91511992307939
# Total error at step 822 is 116.91510696639601
# Total error at step 823 is 116.91509403347412
# Total error at step 824 is 116.91508112429825
# Total error at step 825 is 116.91506823885308
# Total error at step 826 is 116.9150553771232
# Total error at step 827 is 116.91504253909315
# Total error at step 828 is 116.91502972474758
# Total error at step 829 is 116.91501693407119
# Total error at step 830 is 116.91500416704851
# Total error at step 831 is 116.91499142366416
# Total error at step 832 is 116.91497870390292
# Total error at step 833 is 116.91496600774934
# Total error at step 834 is 116.91495333518817
# Total error at step 835 is 116.91494068620402
# Total error at step 836 is 116.91492806078163
# Total error at step 837 is 116.91491545890571
# Total error at step 838 is 116.91490288056082
# Total error at step 839 is 116.91489032573186
# Total error at step 840 is 116.91487779440351
# Total error at step 841 is 116.91486528656037
# Total error at step 842 is 116.91485280218738
# Total error at step 843 is 116.91484034126913
# Total error at step 844 is 116.91482790379045
# Total error at step 845 is 116.91481548973603
# Total error at step 846 is 116.91480309909075
# Total error at step 847 is 116.91479073183937
# Total error at step 848 is 116.91477838796662
# Total error at step 849 is 116.91476606745736
# Total error at step 850 is 116.91475377029637
# Total error at step 851 is 116.91474149646848
# Total error at step 852 is 116.91472924595853
# Total error at step 853 is 116.91471701875132
# Total error at step 854 is 116.9147048148317
# Total error at step 855 is 116.91469263418456
# Total error at step 856 is 116.91468047679476
# Total error at step 857 is 116.91466834264708
# Total error at step 858 is 116.91465623172652
# Total error at step 859 is 116.91464414401794
# Total error at step 860 is 116.91463207950613
# Total error at step 861 is 116.91462003817612
# Total error at step 862 is 116.91460802001279
# Total error at step 863 is 116.91459602500102
# Total error at step 864 is 116.91458405312584
# Total error at step 865 is 116.9145721043721
# Total error at step 866 is 116.9145601787247
# Total error at step 867 is 116.91454827616873
# Total error at step 868 is 116.91453639668904
# Total error at step 869 is 116.91452454027075
# Total error at step 870 is 116.91451270689868
# Total error at step 871 is 116.91450089655788
# Total error at step 872 is 116.91448910923336
# Total error at step 873 is 116.91447734491013
# Total error at step 874 is 116.91446560357318
# Total error at step 875 is 116.9144538852076
# Total error at step 876 is 116.91444218979836
# Total error at step 877 is 116.91443051733049
# Total error at step 878 is 116.91441886778914
# Total error at step 879 is 116.91440724115927
# Total error at step 880 is 116.91439563742603
# Total error at step 881 is 116.91438405657439
# Total error at step 882 is 116.91437249858953
# Total error at step 883 is 116.91436096345645
# Total error at step 884 is 116.9143494511603
# Total error at step 885 is 116.91433796168629
# Total error at step 886 is 116.91432649501938
# Total error at step 887 is 116.91431505114481
# Total error at step 888 is 116.91430363004758
# Total error at step 889 is 116.914292231713
# Total error at step 890 is 116.91428085612618
# Total error at step 891 is 116.91426950327221
# Total error at step 892 is 116.91425817313628
# Total error at step 893 is 116.91424686570359
# Total error at step 894 is 116.91423558095934
# Total error at step 895 is 116.91422431888873
# Total error at step 896 is 116.91421307947687
# Total error at step 897 is 116.91420186270909
# Total error at step 898 is 116.91419066857065
# Total error at step 899 is 116.91417949704658
# Total error at step 900 is 116.91416834812226
# Total error at step 901 is 116.91415722178293
# Total error at step 902 is 116.91414611801382
# Total error at step 903 is 116.91413503680025
# Total error at step 904 is 116.91412397812732
# Total error at step 905 is 116.91411294198053
# Total error at step 906 is 116.91410192834502
# Total error at step 907 is 116.91409093720613
# Total error at step 908 is 116.91407996854916
# Total error at step 909 is 116.9140690223595
# Total error at step 910 is 116.9140580986223
# Total error at step 911 is 116.91404719732306
# Total error at step 912 is 116.91403631844707
# Total error at step 913 is 116.91402546197962
# Total error at step 914 is 116.9140146279061
# Total error at step 915 is 116.9140038162119
# Total error at step 916 is 116.91399302688235
# Total error at step 917 is 116.91398225990284
# Total error at step 918 is 116.91397151525874
# Total error at step 919 is 116.91396079293557
# Total error at step 920 is 116.91395009291853
# Total error at step 921 is 116.9139394151932
# Total error at step 922 is 116.91392875974489
# Total error at step 923 is 116.91391812655917
# Total error at step 924 is 116.91390751562137
# Total error at step 925 is 116.91389692691693
# Total error at step 926 is 116.91388636043139
# Total error at step 927 is 116.9138758161501
# Total error at step 928 is 116.91386529405864
# Total error at step 929 is 116.91385479414242
# Total error at step 930 is 116.91384431638696
# Total error at step 931 is 116.91383386077771
# Total error at step 932 is 116.91382342730029
# Total error at step 933 is 116.91381301594005
# Total error at step 934 is 116.91380262668265
# Total error at step 935 is 116.91379225951351
# Total error at step 936 is 116.91378191441828
# Total error at step 937 is 116.91377159138244
# Total error at step 938 is 116.91376129039159
# Total error at step 939 is 116.91375101143122
# Total error at step 940 is 116.91374075448691
# Total error at step 941 is 116.91373051954433
# Total error at step 942 is 116.91372030658898
# Total error at step 943 is 116.91371011560649
# Total error at step 944 is 116.91369994658245
# Total error at step 945 is 116.91368979950248
# Total error at step 946 is 116.91367967435215
# Total error at step 947 is 116.91366957111723
# Total error at step 948 is 116.91365948978323
# Total error at step 949 is 116.91364943033581
# Total error at step 950 is 116.91363939276069
# Total error at step 951 is 116.91362937704345
# Total error at step 952 is 116.91361938316979
# Total error at step 953 is 116.91360941112538
# Total error at step 954 is 116.91359946089597
# Total error at step 955 is 116.91358953246724
# Total error at step 956 is 116.91357962582475
# Total error at step 957 is 116.91356974095437
# Total error at step 958 is 116.91355987784178
# Total error at step 959 is 116.91355003647267
# Total error at step 960 is 116.9135402168328
# Total error at step 961 is 116.91353041890791
# Total error at step 962 is 116.9135206426838
# Total error at step 963 is 116.91351088814612
# Total error at step 964 is 116.91350115528074
# Total error at step 965 is 116.91349144407336
# Total error at step 966 is 116.9134817545098
# Total error at step 967 is 116.91347208657591
# Total error at step 968 is 116.91346244025739
# Total error at step 969 is 116.91345281554011
# Total error at step 970 is 116.91344321240987
# Total error at step 971 is 116.91343363085247
# Total error at step 972 is 116.91342407085378
# Total error at step 973 is 116.91341453239963
# Total error at step 974 is 116.91340501547585
# Total error at step 975 is 116.91339552006833
# Total error at step 976 is 116.9133860461629
# Total error at step 977 is 116.91337659374541
# Total error at step 978 is 116.91336716280189
# Total error at step 979 is 116.91335775331805
# Total error at step 980 is 116.91334836527989
# Total error at step 981 is 116.91333899867328
# Total error at step 982 is 116.91332965348406
# Total error at step 983 is 116.91332032969835
# Total error at step 984 is 116.91331102730186
# Total error at step 985 is 116.91330174628065
# Total error at step 986 is 116.91329248662069
# Total error at step 987 is 116.91328324830782
# Total error at step 988 is 116.91327403132813
# Total error at step 989 is 116.91326483566748
# Total error at step 990 is 116.9132556613119
# Total error at step 991 is 116.91324650824738
# Total error at step 992 is 116.9132373764599
# Total error at step 993 is 116.91322826593543
# Total error at step 994 is 116.91321917666006
# Total error at step 995 is 116.91321010861974
# Total error at step 996 is 116.91320106180055
# Total error at step 997 is 116.91319203618848
# Total error at step 998 is 116.91318303176962
# Total error at step 999 is 116.91317404852992
# [[ 4.  2.  4.  5.  4.  2.  2.]
#  [ 4.  4.  3.  2.  2.  5.  4.]
#  [ 4.  1.  4.  7.  3.  6.  2.]
#  [ 8. nan  2.  0.  5.  0.  7.]
#  [ 4.  5.  8.  7.  6.  2. nan]]
#
# [[3.88450179 2.57075299 3.74773819 3.69103013 3.45556594 2.35975955
#   3.55853632]
#  [3.77147533 2.49595237 3.63869111 3.58363307 3.35502012 2.29109816
#   3.4549944 ]
#  [4.42075011 2.92564071 4.26510655 4.20057005 3.93260045 2.68552001
#   4.04978571]
#  [4.28027417 2.8326741  4.12957641 4.06709065 3.80763619 2.6001836
#   3.92109771]
#  [6.35441219 4.20533314 6.13068921 6.03792407 5.652743   3.86018224
#   5.82118578]]
